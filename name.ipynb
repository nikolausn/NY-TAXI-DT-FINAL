# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
taxi_train = pd.read_csv("KAGGLE_NY_TAXI/sample_train.csv")

# %%
taxi_train.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
taxi_test = pd.read_csv("KAGGLE_NY_TAXI/sample_test.csv",names=taxi_train.columns.values)

# %%
taxi_test.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2010-03-06 21:13:04.0000003         10.1  2010-03-06 21:13:04 UTC
# 1  2010-03-10 16:19:00.000000128          3.7  2010-03-10 16:19:00 UTC
# 2    2014-02-27 08:50:19.0000006         11.0  2014-02-27 08:50:19 UTC
# 3    2011-02-11 17:46:17.0000005          7.3  2011-02-11 17:46:17 UTC
# 4   2011-07-25 12:48:00.00000074          6.9  2011-07-25 12:48:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.993113        40.755552         -73.969351         40.797908
# 1        -73.948102        40.770608         -73.952923         40.768025
# 2        -73.977236        40.743045         -73.997854         40.719837
# 3        -73.954060        39.603285         -73.977015         40.776712
# 4        -73.978575        40.753067         -73.964632         40.764258
#
#    passenger_count
# 0                1
# 1                1
# 2                1
# 3                3
# 4                1

# %%
import gmaps

# %%
import gmaps.datasets

# %%
gmaps.configure(api_key="AIzaSyBFWqEwtkIQYG-kmTbWPeBLVJ6zr9OFnss") # Your Google API key

# %%
taxi_train_test = taxi_train[(taxi_train.pickup_latitude<=90)&(taxi_train.pickup_latitude>=-90)&(taxi_train.pickup_longitude<=180)&(taxi_train.pickup_longitude>=-180)]

# %%
# load a Numpy array of (latitude, longitude) pairs
locations = gmaps.datasets.load_dataset("taxi_rides")

fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(list(zip(taxi_train_test[0:500].pickup_latitude.values,taxi_train_test[0:500].pickup_longitude.values))))
#fig.add_layer(gmaps.heatmap_layer(locations))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
list(zip(taxi_train_test[0:500].pickup_latitude.values,taxi_train_test[0:500].pickup_longitude.values))
# Out:
# [(40.721319, -73.844311),
#  (40.711303, -74.016048),
#  (40.76127, -73.982738),
#  (40.733143, -73.98713000000001),
#  (40.768008, -73.96809499999999),
#  (40.731629999999996, -74.000964),
#  (40.751661999999996, -73.980002),
#  (40.774138, -73.9513),
#  (40.726713000000004, -74.006462),
#  (40.733872999999996, -73.98065799999999),
#  (40.702737, -73.94414499999999),
#  (0.0, 0.0),
#  (40.768716999999995, -73.95822),
#  (40.761632, -73.984847),
#  (40.773787, -73.87093),
#  (40.751162, -73.99276),
#  (40.737871999999996, -73.987997),
#  (40.739743, -73.982377),
#  (40.760884999999995, -73.976248),
#  (40.766765, -73.95343199999999),
#  (40.751527, -73.98646),
#  (40.744075, -74.003197),
#  (40.763626, -73.95893000000001),
#  (40.738957, -73.98732),
#  (40.792640999999996, -73.964127),
#  (40.76170349121094, -73.95744323730467),
#  (40.735471999999994, -73.998418),
#  (40.745775, -73.978192),
#  (40.746538, -73.977473),
#  (40.767921447753906, -73.9819564819336),
#  (40.779513, -73.980914),
#  (40.712852000000005, -74.016361),
#  (40.739202, -73.988477),
#  (40.78464126586913, -73.97361755371094),
#  (40.752025, -73.979605),
#  (40.735362, -73.994313),
#  (40.734511, -73.99888100000001),
#  (0.0, 0.0),
#  (40.756921999999996, -73.97462)]

# %%
# ?gmaps.heatmap_layer

# %%
sum((taxi_train.pickup_latitude<=90)&(taxi_train.pickup_latitude>=-90)&(taxi_train.pickup_longitude<=180)&(taxi_train.pickup_longitude>=-180))
# Out:
# 999977

# %%
taxi_train.describe()
# Out:
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  1000000.000000    1000000.000000   1000000.000000      999990.000000
# mean        11.348079        -72.526640        39.929008         -72.527860
# std          9.822090         12.057937         7.626154          11.324494
# min        -44.900000      -3377.680935     -3116.285383       -3383.296608
# 25%          6.000000        -73.992060        40.734965         -73.991385
# 50%          8.500000        -73.981792        40.752695         -73.980135
# 75%         12.500000        -73.967094        40.767154         -73.963654
# max        500.000000       2522.271325      2621.628430          45.581619
#
#        dropoff_latitude  passenger_count
# count     999990.000000   1000000.000000
# mean          39.919954         1.684924
# std            8.201418         1.323911
# min        -3114.338567         0.000000
# 25%           40.734046         1.000000
# 50%           40.753166         1.000000
# 75%           40.768129         2.000000
# max         1651.553433       208.000000

# %%
plt.figure(figsize=(7,5))
taxi_train.pickup_latitude.hist()
plt.title("Pickup Latitude Before Preprocessing")
plt.xlabel("Latitude")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7,5))
taxi_train.pickup_longitude.hist()
plt.title("Pickup Longitude Before Preprocessing")
plt.xlabel("Latitude")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The latitude of New York City, NY, USA is 40.730610, and the longitude is -73.935242

# %%
taxi_train_test[(taxi_train_test.pickup_latitude>40.6)&(taxi_train_test.pickup_latitude<40.9)].pickup_latitude.hist()

# %%
taxi_train_test[(taxi_train_test.pickup_longitude>-74.1)&(taxi_train_test.pickup_longitude<-73.7)].pickup_longitude.hist()

# %%
# base from the observation above, we set the boundary for latitude and longitude
max_lat = 40.9
min_lat = 40.6
max_lon = -73.7
min_lon = -74.1
taxi_clean = taxi_train[(taxi_train.pickup_latitude>min_lat)&
           (taxi_train.pickup_latitude<max_lat)&
           (taxi_train.dropoff_latitude>min_lat)&
           (taxi_train.dropoff_latitude<max_lat)&
           (taxi_train.pickup_longitude>min_lon)&
           (taxi_train.pickup_longitude<max_lon)&
           (taxi_train.dropoff_longitude>min_lon)&
           (taxi_train.dropoff_longitude<max_lon)]

# %%
taxi_test_clean = taxi_test[(taxi_test.pickup_latitude>min_lat)&
           (taxi_test.pickup_latitude<max_lat)&
           (taxi_test.dropoff_latitude>min_lat)&
           (taxi_test.dropoff_latitude<max_lat)&
           (taxi_test.pickup_longitude>min_lon)&
           (taxi_test.pickup_longitude<max_lon)&
           (taxi_test.dropoff_longitude>min_lon)&
           (taxi_test.dropoff_longitude<max_lon)]

# %%
taxi_test_clean = taxi_test_clean[taxi_test_clean.fare_amount>0]

# %%
# compute distance
import geopy.distance

distances = []
for coor1,coor2 in zip(zip(taxi_test_clean.pickup_latitude,taxi_test_clean.pickup_longitude),zip(taxi_test_clean.dropoff_latitude,taxi_test_clean.dropoff_longitude)):
    distances.append(geopy.distance.vincenty(coor1, coor2).miles)

# %%
taxi_test_clean["distance"] = distances

# %%
plt.figure(figsize=(7,5))
taxi_clean.pickup_latitude.hist()
plt.title("Pickup Latitude Distribution")
plt.xlabel("Latitude")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7,5))
taxi_clean.pickup_longitude.hist()
plt.title("Pickup Longitude Distribution")
plt.xlabel("Longitude")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7,5))
taxi_clean.dropoff_latitude.hist()
plt.title("Dropoff Latitude Distribution")
plt.xlabel("Latitude")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(7,5))
taxi_clean.dropoff_longitude.hist()
plt.title("Dropoff Longitude Distribution")
plt.xlabel("Longitude")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
taxi_clean = taxi_clean[taxi_clean.fare_amount>0]

# %%
taxi_clean.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  975119.000000     975119.000000    975119.000000      975119.000000
# mean       11.170748        -73.975468        40.750931         -73.974267
# std         9.109029          0.034118         0.026656           0.032803
# min         0.010000        -74.099610        40.600037         -74.099453
# 25%         6.000000        -73.992261        40.736619         -73.991527
# 50%         8.500000        -73.982086        40.753422         -73.980580
# 75%        12.500000        -73.968359        40.767562         -73.965387
# max       500.000000        -73.700438        40.899536         -73.700155
#
#        dropoff_latitude  passenger_count
# count     975119.000000    975119.000000
# mean          40.751414         1.684945
# std            0.030168         1.307763
# min           40.600014         0.000000
# 25%           40.735802         1.000000
# 50%           40.753934         1.000000
# 75%           40.768414         2.000000
# max           40.899980         6.000000

# %%
plt.figure(figsize=(7,5))
taxi_clean[taxi_clean.fare_amount<100].fare_amount.hist()
plt.title("Fare amount Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# compute distance
import geopy.distance

distances = []
for coor1,coor2 in zip(zip(taxi_clean.pickup_latitude,taxi_clean.pickup_longitude),zip(taxi_clean.dropoff_latitude,taxi_clean.dropoff_longitude)):
    distances.append(geopy.distance.vincenty(coor1, coor2).miles)

# %%
# ?geopy.distance

# %%
taxi_clean["distance"] = distances

# %%
taxi_clean.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance
# 0                1  0.639764
# 1                1  5.246511
# 2                2  0.863167
# 3                1  1.737223
# 4                1  1.241710

# %%
plt.figure(figsize=(5,5))
taxi_clean.distance.hist()
plt.title("Distance Distribution")
plt.xlabel("Distance")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10,10))
plt.scatter(taxi_clean.pickup_longitude,taxi_clean.pickup_latitude)
plt.title("Pickup Location")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
plt.figure(figsize=(10,10))
plt.scatter(taxi_clean.dropoff_longitude,taxi_clean.dropoff_latitude)
plt.title("Dropoff Location")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %% [raw]
# # cluster the location using kmeans
# from sklearn.cluster import KMeans
# import random
#
# random.seed(1984)
#
# #?KMeans
#
# kmeaan_dropoff = KMeans(n_clusters=100)
# kmeaan_dropoff.fit(taxi_clean.loc[:,["dropoff_longitude","dropoff_latitude"]].as_matrix())

# %% [raw]
# pd.DataFrame(kmeaan_dropoff.predict(taxi_clean.loc[:,["dropoff_longitude","dropoff_latitude"]].as_matrix())).iloc[:,0].hist()

# %% [raw]
# import matplotlib
#
# cmap = matplotlib.cm.get_cmap('Dark2')
# norm = matplotlib.colors.Normalize(vmin=0, vmax=99)
#
# colors = [cmap(norm(x)) for x in kmeaan_dropoff.predict(taxi_clean.loc[:,["dropoff_longitude","dropoff_latitude"]].as_matrix())]
# plt.scatter(taxi_clean.dropoff_longitude,taxi_clean.dropoff_latitude,color=colors,cmap=cmap)

# %%
taxi_clean.to_csv("taxi_clean.csv")

# %% [markdown]
# Try Linear Regression using all the features for baseline

# %%
from sklearn.linear_model import LinearRegression

# %%
taxi_clean.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance
# 0                1  0.639764
# 1                1  5.246511
# 2                2  0.863167
# 3                1  1.737223
# 4                1  1.241710

# %%
X_train = taxi_clean.loc[:,["pickup_latitude","pickup_longitude","dropoff_latitude","dropoff_longitude","passenger_count"]].as_matrix()
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
y_train = taxi_clean.fare_amount.values

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X = X_train
y = y_train

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                 9.987e+04
# Date:                Wed, 24 Oct 2018   Prob (F-statistic):               0.00
# Time:                        11:34:26   Log-Likelihood:            -3.3363e+06
# No. Observations:              975119   AIC:                         6.673e+06
# Df Residuals:                  975113   BIC:                         6.673e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.749e+04     25.104    696.624      0.000    1.74e+04    1.75e+04
# x1           -54.9216      0.311   -176.506      0.000     -55.531     -54.312
# x2            93.4636      0.231    404.358      0.000      93.011      93.917
# x3           -46.7468      0.276   -169.271      0.000     -47.288     -46.205
# x4            86.7823      0.241    359.401      0.000      86.309      87.256
# x5             0.0870      0.006     15.158      0.000       0.076       0.098
# ==============================================================================
# Omnibus:                   755799.676   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        303479260.010
# Skew:                           2.647   Prob(JB):                         0.00
# Kurtosis:                      89.263   Cond. No.                     4.00e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
est2.mse_resid
# Out:
# 54.87324010601942

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_train_pred = regr.predict(X_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_train, y_train_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_train, y_train_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_train, y_train_pred)))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_train, y_train_pred))
# Out:
# Coefficients:
#  [-5.49216265e+01  9.34636352e+01 -4.67467650e+01  8.67822541e+01
#   8.69525421e-02]
# Mean squared error: 54.87
# Root Mean squared error: 7.41
# Mean Absolute error: 2.20
# Variance score: 0.34

# %%
regr.intercept_
# Out:
# 17487.79819706069

# %%
from sklearn.tree import DecisionTreeRegressor

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=20)
regr_1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=20, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
y_train_pred = regr_1.predict(X_train)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_train, y_train_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_train, y_train_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_train, y_train_pred)))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_train, y_train_pred))
# Out:
# Mean squared error: 10.58
# Root Mean squared error: 3.25
# Mean Absolute error: 1.41
# Variance score: 0.87

# %%
y_train[:10]
# Out:
# array([ 4.5, 16.9,  5.7,  7.7,  5.3, 12.1,  7.5, 16.5,  9. ,  8.9])

# %%
y_train_pred[:10]
# Out:
# array([ 4.93134328, 17.65263158,  7.28378474, 10.15930628,  7.27878898,
#        10.15930628,  7.28378474, 14.29962535,  6.01279548, 10.15930628])

# %%
X_test = taxi_test_clean.loc[:,["pickup_latitude","pickup_longitude","dropoff_latitude","dropoff_longitude","passenger_count"]].as_matrix()
y_test = taxi_test_clean.fare_amount.values
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
# Make predictions using the testing set
y_test_pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_test_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_test_pred)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_test_pred))
# Out:
# Coefficients:
#  [-5.49216265e+01  9.34636352e+01 -4.67467650e+01  8.67822541e+01
#   8.69525421e-02]
# Mean squared error: 53.36
# Root Mean squared error: 7.30
# Mean Absolute error: 2.20
# Variance score: 0.34

# %%
# Make predictions using the testing set
y_test_pred = regr_1.predict(X_test)


print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_test_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_test_pred)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_test_pred))
# Out:
# Mean squared error: 21.94
# Root Mean squared error: 4.68
# Mean Absolute error: 1.57
# Variance score: 0.73

# %% [markdown]
# ### Using only distance and passenger_count

# %%
X_train_d = taxi_clean.loc[:,["distance","passenger_count"]].as_matrix()
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Create linear regression object
regr_d = linear_model.LinearRegression()

# Train the model using the training sets
regr_d.fit(X_train_d, y_train)

# Make predictions using the testing set
y_train_pred = regr_d.predict(X_train_d)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_train, y_train_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_train, y_train_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_train, y_train_pred)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_train, y_train_pred))
# Out:
# Coefficients:
#  [-5.49216265e+01  9.34636352e+01 -4.67467650e+01  8.67822541e+01
#   8.69525421e-02]
# Mean squared error: 20.82
# Root Mean squared error: 4.56
# Mean Absolute error: 1.53
# Variance score: 0.75

# %%
X_test_d = taxi_test_clean.loc[:,["distance","passenger_count"]].as_matrix()
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
# Make predictions using the testing set
y_test_pred = regr_d.predict(X_test_d)

# The coefficients
print('Coefficients: \n', regr_d.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_test_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_test_pred)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_test_pred))
# Out:
# Coefficients:
#  [3.65123841 0.03588433]
# Mean squared error: 19.58
# Root Mean squared error: 4.42
# Mean Absolute error: 1.53
# Variance score: 0.76

# %%
from sklearn.tree import DecisionTreeRegressor

# Fit regression model
regr_1d = DecisionTreeRegressor(max_depth=20)
regr_1d.fit(X_train_d, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=20, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
# Make predictions using the testing set
y_test_pred = regr_1d.predict(X_test_d)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_test_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_test_pred)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_test_pred))
# Out:
# Mean squared error: 22.66
# Root Mean squared error: 4.76
# Mean Absolute error: 1.55
# Variance score: 0.72

# %% [markdown]
# ### scrutinize the time variable

# %%
from datetime import datetime

def extract_time(time_str):
    #datetime_object = datetime.strptime('2010-03-06 21:13:04 UTC', '%Y-%m-%d %H:%M:%S UTC')
    datetime_object = datetime.strptime(time_str, '%Y-%m-%d %H:%M:%S UTC')
    return (datetime_object.year,datetime_object.month,datetime_object.day,datetime_object.weekday(),datetime_object.hour)

# %%
taxi_clean = taxi_clean.reset_index(drop=True)
time_pd = pd.DataFrame(taxi_clean.pickup_datetime.apply(lambda x:extract_time(x)).values.tolist(),columns=["year","month","date","dayofweek","hour"])
taxi_clean_2 = taxi_clean.join(time_pd)

# %%
print(taxi_clean.shape)
print(time_pd.shape)
# Out:
# (975119, 9)
# (975119, 5)

# %%
taxi_test_clean = taxi_test_clean.reset_index(drop=True)
time_pd = pd.DataFrame(taxi_test_clean.pickup_datetime.apply(lambda x:extract_time(x)).values.tolist(),columns=["year","month","date","dayofweek","hour"])
time_pd.head()
#taxi_test_clean.pickup_datetime.apply(lambda x:extract_time(x)).values
#,columns=["year","month","day","weekday","hour"]
# Out:
#    year  month  date  dayofweek  hour
# 0  2010      3     6          5    21
# 1  2010      3    10          2    16
# 2  2014      2    27          3     8
# 3  2011      7    25          0    12
# 4  2014      7    23          2    10

# %%
taxi_test_clean_2 = taxi_test_clean.join(time_pd)

# %%
taxi_clean_2.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance  year  month  date  dayofweek  hour
# 0                1  0.639764  2009      6    15          0    17
# 1                1  5.246511  2010      1     5          1    16
# 2                2  0.863167  2011      8    18          3     0
# 3                1  1.737223  2012      4    21          5     4
# 4                1  1.241710  2010      3     9          1     7

# %%
X_train = taxi_clean_2.loc[:,["pickup_longitude","pickup_latitude","dropoff_longitude","dropoff_latitude","passenger_count","distance","year","month","date","dayofweek","hour"]]

# %%
X_train.head()
# Out:
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance  year  month  date  dayofweek  hour
# 0                1  0.639764  2009      6    15          0    17
# 1                1  5.246511  2010      1     5          1    16
# 2                2  0.863167  2011      8    18          3     0
# 3                1  1.737223  2012      4    21          5     4
# 4                1  1.241710  2010      3     9          1     7

# %%
X_test = taxi_test_clean_2.loc[:,["pickup_longitude","pickup_latitude","dropoff_longitude","dropoff_latitude","passenger_count","distance","year","month","date","dayofweek","hour"]]

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X = X_train.as_matrix()
y = y_train

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                 2.931e+05
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):               0.00
# Time:                        20:30:47   Log-Likelihood:            -2.8260e+06
# No. Observations:              975119   AIC:                         5.652e+06
# Df Residuals:                  975107   BIC:                         5.652e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.6107     19.119    102.079      0.000    1914.139    1989.082
# x1            20.4286      0.148    138.292      0.000      20.139      20.718
# x2             0.5932      0.189      3.135      0.002       0.222       0.964
# x3            10.0510      0.155     65.002      0.000       9.748      10.354
# x4           -17.7469      0.165   -107.475      0.000     -18.071     -17.423
# x5             0.0342      0.003     10.043      0.000       0.028       0.041
# x6             3.3995      0.003   1321.160      0.000       3.394       3.405
# x7             0.5000      0.002    208.006      0.000       0.495       0.505
# x8             0.0692      0.001     53.105      0.000       0.067       0.072
# x9             0.0010      0.001      2.045      0.041    4.37e-05       0.002
# x10           -0.0460      0.002    -20.058      0.000      -0.050      -0.042
# x11            0.0112      0.001     16.298      0.000       0.010       0.013
# ==============================================================================
# Omnibus:                  1737809.950   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      22419721791.569
# Skew:                          11.947   Prob(JB):                         0.00
# Kurtosis:                     745.450   Cond. No.                     8.67e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.67e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train.columns
# Out:
# Index(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'distance', 'year', 'month',
#        'date', 'dayofweek', 'hour'],
#       dtype='object')

# %%
X2_test = sm.add_constant(X_test)

y_pred2 = est2.predict(X2_test)

# %%
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred2))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_pred2)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_pred2)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred2))
# Out:
# Mean squared error: 18.07
# Root Mean squared error: 4.25
# Mean Absolute error: 1.49
# Variance score: 0.78

# %%
from sklearn.tree import DecisionTreeRegressor

# Fit regression model
regr_1d = DecisionTreeRegressor(max_depth=10)
regr_1d.fit(X_train.as_matrix(), y_train)
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# DecisionTreeRegressor(criterion='mse', max_depth=10, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
# Make predictions using the testing set
y_test_pred = regr_1d.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_test_pred))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_test_pred)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_test_pred))
# Out:
# Mean squared error: 14.41
# Root Mean squared error: 3.80
# Mean Absolute error: 1.39
# Variance score: 0.82

# %%
# cluster the location to make a new feature vector
# cluster the location using kmeans
from sklearn.cluster import KMeans
import random

random.seed(1984)

#?KMeans

kmeaan_dropoff = KMeans(n_clusters=30)
kmeaan_dropoff.fit(taxi_clean.loc[:,["dropoff_longitude","dropoff_latitude"]].as_matrix())
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=30, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
random.seed(1984)


kmeaan_pickup = KMeans(n_clusters=30)
kmeaan_pickup.fit(taxi_clean.loc[:,["pickup_latitude","pickup_longitude"]].as_matrix())
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=30, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
pickup_cluster = kmeaan_pickup.transform(taxi_clean.loc[:,["pickup_latitude","pickup_longitude"]].as_matrix())
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
labels = ["Pickup {}".format(x) for x in range(30)]
pd.DataFrame(pickup_cluster,columns=labels).head()
# Out:
#    Pickup 0  Pickup 1  Pickup 2  Pickup 3  Pickup 4  Pickup 5  Pickup 6  \
# 0  0.148392  0.120118  0.095730  0.056979  0.148336  0.147877  0.135349
# 1  0.036403  0.083874  0.240129  0.159085  0.073813  0.026487  0.058018
# 2  0.024586  0.028919  0.228843  0.114068  0.015496  0.039624  0.010638
# 3  0.006965  0.047982  0.220108  0.124315  0.043913  0.011521  0.022962
# 4  0.037891  0.013355  0.219966  0.098970  0.016339  0.051235  0.016765
#
#    Pickup 7  Pickup 8  Pickup 9    ...      Pickup 20  Pickup 21  Pickup 22  \
# 0  0.145407  0.125644  0.149564    ...       0.145429   0.011899   0.140015
# 1  0.108132  0.061618  0.045925    ...       0.089050   0.183927   0.036896
# 2  0.048449  0.083632  0.014147    ...       0.029617   0.155401   0.031584
# 3  0.076279  0.058370  0.017202    ...       0.057842   0.155119   0.004593
# 4  0.037821  0.088149  0.029310    ...       0.021746   0.143312   0.041494
#
#    Pickup 23  Pickup 24  Pickup 25  Pickup 26  Pickup 27  Pickup 28  Pickup 29
# 0   0.153224   0.144468   0.125300   0.161250   0.130237   0.163756   0.057153
# 1   0.053692   0.061924   0.116229   0.034422   0.068795   0.086188   0.125976
# 2   0.010062   0.002108   0.056905   0.027691   0.014358   0.129029   0.088583
# 3   0.027066   0.030574   0.081333   0.019842   0.033503   0.101043   0.092909
# 4   0.025958   0.015157   0.041969   0.043458   0.007103   0.136445   0.075734
#
# [5 rows x 30 columns]

# %%
taxi_clean_3 = taxi_clean_2.join(pd.DataFrame(pickup_cluster,columns=labels))

# %%
pickup_cluster_test = kmeaan_pickup.transform(taxi_test_clean.loc[:,["pickup_latitude","pickup_longitude"]].as_matrix())
labels = ["Pickup {}".format(x) for x in range(30)]
taxi_test_clean_3 = taxi_test_clean_2.join(pd.DataFrame(pickup_cluster_test,columns=labels))
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
dropoff_cluster = kmeaan_dropoff.transform(taxi_clean.loc[:,["dropoff_latitude","dropoff_longitude"]].as_matrix())
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
labels = ["Dropoff {}".format(x) for x in range(30)]
pd.DataFrame(dropoff_cluster,columns=labels).head()
# Out:
#     Dropoff 0   Dropoff 1   Dropoff 2   Dropoff 3   Dropoff 4   Dropoff 5  \
# 0  162.125502  162.094246  162.127177  161.918508  162.138567  162.144938
# 1  162.272121  162.240889  162.273814  162.065156  162.285189  162.291585
# 2  162.258347  162.227130  162.260052  162.051401  162.271417  162.277830
# 3  162.263902  162.232683  162.265605  162.056953  162.276972  162.283382
# 4  162.257381  162.226140  162.259068  162.050405  162.270448  162.276835
#
#     Dropoff 6   Dropoff 7   Dropoff 8   Dropoff 9     ...      Dropoff 20  \
# 0  162.045335  162.063541  162.160604  162.130367     ...      162.148902
# 1  162.191963  162.210197  162.307259  162.277008     ...      162.295536
# 2  162.178195  162.196448  162.293509  162.263249     ...      162.281773
# 3  162.183750  162.201999  162.299061  162.268801     ...      162.287326
# 4  162.177220  162.195444  162.292506  162.262261     ...      162.280791
#
#    Dropoff 21  Dropoff 22  Dropoff 23  Dropoff 24  Dropoff 25  Dropoff 26  \
# 0  162.127892  162.114368  162.163110  162.138887  162.122252  162.124094
# 1  162.274525  162.260990  162.309779  162.285518  162.268866  162.270718
anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
taxi_test_clean_3.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2010-03-06 21:13:04.0000003         10.1  2010-03-06 21:13:04 UTC
# 1  2010-03-10 16:19:00.000000128          3.7  2010-03-10 16:19:00 UTC
# 2    2014-02-27 08:50:19.0000006         11.0  2014-02-27 08:50:19 UTC
# 3   2011-07-25 12:48:00.00000074          6.9  2011-07-25 12:48:00 UTC
# 4    2014-07-23 10:16:44.0000001         20.5  2014-07-23 10:16:44 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.993113        40.755552         -73.969351         40.797908
# 1        -73.948102        40.770608         -73.952923         40.768025
# 2        -73.977236        40.743045         -73.997854         40.719837
# 3        -73.978575        40.753067         -73.964632         40.764258
# 4        -73.997789        40.741463         -73.984134         40.780437
#
#    passenger_count  distance  year     ...      Dropoff 20  Dropoff 21  \
# 0                1  3.177380  2010     ...      162.299771  162.278761
# 1                1  0.309408  2010     ...      162.267023  162.246013
# 2                1  1.932819  2014     ...      162.264729  162.243716
# 3                1  1.063729  2011     ...      162.272639  162.251628
# 4                1  2.783113  2014     ...      162.297869  162.276858
#
#    Dropoff 22  Dropoff 23  Dropoff 24  Dropoff 25  Dropoff 26  Dropoff 27  \
# 0  162.265230  162.314001  162.289754  162.273109  162.274957  162.219939
# 1  162.232480  162.281260  162.257006  162.240357  162.242207  162.187188
# 2  162.230168  162.279012  162.254706  162.238034  162.239899  162.184868
# 3  162.238092  162.286883  162.262620  162.245968  162.247820  162.192799
# 4  162.263322  162.312115  162.287850  162.271197  162.273050  162.218028
#
#    Dropoff 28  Dropoff 29
# 0  162.152593  162.221519
# 1  162.119848  162.188764
# 2  162.117577  162.186416
# 3  162.125467  162.194370
# 4  162.150698  162.219599
#
# [5 rows x 74 columns]

# %%
X_train = taxi_clean_3.iloc[:,7:]

# %%
X_test = taxi_test_clean_3.iloc[:,7:]

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X = X_train.as_matrix()
y = y_train

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
# /Volumes/HD-500GB/Users/nikolausn/Applications/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                 8.378e+04
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):               0.00
# Time:                        22:53:54   Log-Likelihood:            -2.8115e+06
# No. Observations:              975119   AIC:                         5.623e+06
# Df Residuals:                  975078   BIC:                         5.624e+06
# Df Model:                          40
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       
# x51        -3.567e+10   7.13e+08    -50.059      0.000   -3.71e+10   -3.43e+10
# x52        -7.238e+09   1.24e+08    -58.362      0.000   -7.48e+09   -6.99e+09
# x53         -7.94e+08   1.55e+08     -5.135      0.000    -1.1e+09   -4.91e+08
# x54         1.255e+10   3.25e+08     38.582      0.000    1.19e+10    1.32e+10
# x55        -1.793e+08   6.76e+07     -2.653      0.008   -3.12e+08   -4.68e+07
# x56         2.324e+09   2.69e+08      8.646      0.000     1.8e+09    2.85e+09
# x57         2.566e+10   4.09e+08     62.785      0.000    2.49e+10    2.65e+10
# x58         1.809e+09    1.8e+08     10.063      0.000    1.46e+09    2.16e+09
# x59         2.703e+09   1.61e+08     16.827      0.000    2.39e+09    3.02e+09
# x60        -6.813e+09    1.2e+08    -56.970      0.000   -7.05e+09   -6.58e+09
# x61          1.97e+10      3e+08     65.617      0.000    1.91e+10    2.03e+10
# x62        -7.196e+09   1.17e+08    -61.375      0.000   -7.43e+09   -6.97e+09
# x63        -1.622e+10   3.31e+08    -48.944      0.000   -1.69e+10   -1.56e+10
# x64        -7.371e+09   1.18e+08    -62.315      0.000    -7.6e+09   -7.14e+09
# x65          9.54e+09    1.6e+08     59.610      0.000    9.23e+09    9.85e+09
# x66         1.782e+09   1.09e+08     16.400      0.000    1.57e+09       2e+09
# x67         2.169e+09   3.62e+08      6.000      0.000    1.46e+09    2.88e+09
# ==============================================================================
# Omnibus:                  1745930.065   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      24576183311.392
# Skew:                          12.046   Prob(JB):                         0.00
# Kurtosis:                     780.366   Cond. No.                     1.00e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.71e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X2_test = sm.add_constant(X_test)
y_pred2 = est2.predict(X2_test)
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred2))
print("Root Mean squared error: %.2f"
      % np.sqrt(mean_squared_error(y_test, y_pred2)))
print("Mean Absolute error: %.2f"
      % np.sqrt(mean_absolute_error(y_test, y_pred2)))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred2))
# Out:
# Mean squared error: 17.45
# Root Mean squared error: 4.18
# Mean Absolute error: 1.46
# Variance score: 0.78

# %%
X_test
# Out:
#        passenger_count   distance  year  month  date  dayofweek  hour  \
# 0                    1   3.177380  2010      3     6          5    21
# 1                    1   0.309408  2010      3    10          2    16
# 2                    1   1.932819  2014      2    27          3     8
# 3                    1   1.063729  2011      7    25          0    12
# 4                    1   2.783113  2014      7    23          2    10
# 5                    1   3.804550  2015      3    27          4    20
# 6                    1   1.016208  2009      3     4          2    19
# 7                    1   3.547288  2014      1    13          0    16
# 8                    1   0.934760  2010      5    10          0    12
# 9                    5   3.887567  2011      2    25          4    23
# 10                   1   1.490802  2011      4     2          5    21
# 11                   1   1.749581  2013     11     6          2    16
# 12                   2   1.101290  2014      8     2          5     0
# 13                   1   2.120899  2011      7    14          3     8
# 14                   2   0.909020  2012      2    13          0     0
# 15                   1   0.404209  2012      5    31          3     8
# 16                   3   2.043355  2014      5     2          4     1
# 17                   1   1.035987  2014      9     2          1     8
